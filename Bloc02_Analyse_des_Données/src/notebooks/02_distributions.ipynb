# %% [markdown]
# **Distributions**

# %%
import pandas as pd

# %%
df_xray = pd.read_csv("../../../data/processed/data_clean.csv")

# %%
df_distribution = df_xray.drop(columns=["Path"])
print(df_distribution.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 223413 entries, 0 to 223412
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Sex                         223413 non-null  str
#  1   Age                         223413 non-null  int64
#  2   Frontal/Lateral             223413 non-null  str
#  3   AP/PA                       191026 non-null  str
#  4   No Finding                  22380 non-null   float64
#  5   Enlarged Cardiomediastinum  44838 non-null   float64
#  6   Cardiomegaly                46203 non-null   float64
#  7   Lung Opacity                117778 non-null  float64
#  8   Lung Lesion                 11944 non-null   float64
#  9   Edema                       85956 non-null   float64
#  10  Consolidation               70621 non-null   float64
#  11  Pneumonia                   27608 non-null   float64
#  12  Atelectasis                 68443 non-null   float64
# ...

# %%
print(df_distribution["No Finding"].value_counts())
# Out:
# No Finding
# 1.0    22380
# Name: count, dtype: int64
